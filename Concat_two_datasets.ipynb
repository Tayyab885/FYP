# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("chronic_kidney_disease.csv")
df.head()
# Out:
#    48  80  1.020  1  0       ?    normal  notpresent notpresent.1  121  ...  \
# 0   7  50  1.020  4  0       ?    normal  notpresent   notpresent    ?  ...
# 1  62  80  1.010  2  3  normal    normal  notpresent   notpresent  423  ...
# 2  48  70  1.005  4  0  normal  abnormal     present   notpresent  117  ...
# 3  51  80  1.010  2  0  normal    normal  notpresent   notpresent  106  ...
# 4  60  90  1.015  3  0       ?         ?  notpresent   notpresent   74  ...
#
#    44  7800  5.2  yes yes.1  no  good no.1 no.2  ckd
# 0  38  6000    ?   no    no  no  good   no   no  ckd
# 1  31  7500    ?   no   yes  no  poor   no  yes  ckd
# 2  32  6700  3.9  yes    no  no  poor  yes  yes  ckd
# 3  35  7300  4.6   no    no  no  good   no   no  ckd
# 4  39  7800  4.4  yes   yes  no  good  yes   no  ckd
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (399, 25)

# %%
df = df.replace('?', np.NaN)

# %%
df.head()
# Out:
#    48  80  1.020  1  0       ?    normal  notpresent notpresent.1  121  ...  \
# 0   7  50  1.020  4  0     NaN    normal  notpresent   notpresent  NaN  ...
# 1  62  80  1.010  2  3  normal    normal  notpresent   notpresent  423  ...
# 2  48  70  1.005  4  0  normal  abnormal     present   notpresent  117  ...
# 3  51  80  1.010  2  0  normal    normal  notpresent   notpresent  106  ...
# 4  60  90  1.015  3  0     NaN       NaN  notpresent   notpresent   74  ...
#
#    44  7800  5.2  yes yes.1  no  good no.1 no.2  ckd
# 0  38  6000  NaN   no    no  no  good   no   no  ckd
# 1  31  7500  NaN   no   yes  no  poor   no  yes  ckd
# 2  32  6700  3.9  yes    no  no  poor  yes  yes  ckd
# 3  35  7300  4.6   no    no  no  good   no   no  ckd
# 4  39  7800  4.4  yes   yes  no  good  yes   no  ckd
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['48', '80', '1.020', '1', '0', '?', 'normal', 'notpresent',
#        'notpresent.1', '121', '36', '1.2', '?.1', '?.2', '15.4', '44', '7800',
#        '5.2', 'yes', 'yes.1', 'no', 'good', 'no.1', 'no.2', 'ckd'],
#       dtype='object')

# %%
df = df.rename(columns = {'?':np.nan})

# %%
df.head()
# Out:
#    48  80  1.020  1  0     NaN    normal  notpresent notpresent.1  121  ...  \
# 0   7  50  1.020  4  0     NaN    normal  notpresent   notpresent  NaN  ...
# 1  62  80  1.010  2  3  normal    normal  notpresent   notpresent  423  ...
# 2  48  70  1.005  4  0  normal  abnormal     present   notpresent  117  ...
# 3  51  80  1.010  2  0  normal    normal  notpresent   notpresent  106  ...
# 4  60  90  1.015  3  0     NaN       NaN  notpresent   notpresent   74  ...
#
#    44  7800  5.2  yes yes.1  no  good no.1 no.2  ckd
# 0  38  6000  NaN   no    no  no  good   no   no  ckd
# 1  31  7500  NaN   no   yes  no  poor   no  yes  ckd
# 2  32  6700  3.9  yes    no  no  poor  yes  yes  ckd
# 3  35  7300  4.6   no    no  no  good   no   no  ckd
# 4  39  7800  4.4  yes   yes  no  good  yes   no  ckd
#
# [5 rows x 25 columns]

# %%
df
# Out:
#      48  80  1.020  1  0     NaN    normal  notpresent notpresent.1  121  ...  \
# 0     7  50  1.020  4  0     NaN    normal  notpresent   notpresent  NaN  ...
# 1    62  80  1.010  2  3  normal    normal  notpresent   notpresent  423  ...
# 2    48  70  1.005  4  0  normal  abnormal     present   notpresent  117  ...
# 3    51  80  1.010  2  0  normal    normal  notpresent   notpresent  106  ...
# 4    60  90  1.015  3  0     NaN       NaN  notpresent   notpresent   74  ...
# ..   ..  ..    ... .. ..     ...       ...         ...          ...  ...  ...
# 394  55  80  1.020  0  0  normal    normal  notpresent   notpresent  140  ...
# 395  42  70  1.025  0  0  normal    normal  notpresent   notpresent   75  ...
# 396  12  80  1.020  0  0  normal    normal  notpresent   notpresent  100  ...
# 397  17  60  1.025  0  0  normal    normal  notpresent   notpresent  114  ...
# 398  58  80  1.025  0  0  normal    normal  notpresent   notpresent  131  ...
#
#      44  7800  5.2  yes yes.1  no  good no.1 no.2     ckd
# 0    38  6000  NaN   no    no  no  good   no   no     ckd
# 1    31  7500  NaN   no   yes  no  poor   no  yes     ckd
# 2    32  6700  3.9  yes    no  no  poor  yes  yes     ckd
# 3    35  7300  4.6   no    no  no  good   no   no     ckd
# 4    39  7800  4.4  yes   yes  no  good  yes   no     ckd
# ..   ..   ...  ...  ...   ...  ..   ...  ...  ...     ...
# 394  47  6700  4.9   no    no  no  good   no   no  notckd
# 395  54  7800  6.2   no    no  no  good   no   no  notckd
# 396  49  6600  5.4   no    no  no  good   no   no  notckd
# 397  51  7200  5.9   no    no  no  good   no   no  notckd
# 398  53  6800  6.1   no    no  no  good   no   no  notckd
#
# [399 rows x 25 columns]

# %%
new_columns = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
       'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
       'appet', 'pe', 'ane', 'classification']

# %%
df.columns
# Out:
# Index([          '48',           '80',        '1.020',            '1',
#                   '0',            nan,       'normal',   'notpresent',
#        'notpresent.1',          '121',           '36',          '1.2',
#                 '?.1',          '?.2',         '15.4',           '44',
#                '7800',          '5.2',          'yes',        'yes.1',
#                  'no',         'good',         'no.1',         'no.2',
#                 'ckd'],
#       dtype='object')

# %%
df.columns = new_columns

# %%
df.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...  \
# 0   7  50  1.020  4  0     NaN    normal  notpresent  notpresent  NaN  ...
# 1  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 2  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 3  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
# 4  60  90  1.015  3  0     NaN       NaN  notpresent  notpresent   74  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  38  6000  NaN   no   no  no  good   no   no            ckd
# 1  31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 2  32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 3  35  7300  4.6   no   no  no  good   no   no            ckd
# 4  39  7800  4.4  yes  yes  no  good  yes   no            ckd
#
# [5 rows x 25 columns]

# %%
df2 = pd.read_csv("kidney_disease_train.csv")
df2.head()
# Out:
#     id   age     bp     sg   al   su     rbc        pc         pcc  \
# 0  157  62.0   70.0  1.025  3.0  0.0  normal  abnormal  notpresent
# 1  109  54.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 2   17  47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 3  347  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent
# 4   24  42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent
#
#            ba  ...   pcv    wc   rc  htn   dm  cad  appet  pe ane  \
# 0  notpresent  ...  39.0  7900  3.9  yes  yes   no   good  no  no
# 1  notpresent  ...   NaN   NaN  NaN   no  yes   no   good  no  no
# 2  notpresent  ...   NaN   NaN  NaN  yes   no   no   poor  no  no
# 3  notpresent  ...  43.0  7200  5.5   no   no   no   good  no  no
# 4     present  ...  39.0  8300  4.6  yes   no   no   poor  no  no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3         notckd
# 4            ckd
#
# [5 rows x 26 columns]

# %%
df2.drop('id',axis = 1,inplace = True)

# %%
df2.head()
# Out:
#     age     bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  62.0   70.0  1.025  3.0  0.0  normal  abnormal  notpresent  notpresent
# 1  54.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 2  47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 3  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 4  42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent     present
#
#      bgr  ...   pcv    wc   rc  htn   dm  cad appet  pe ane classification
# 0  122.0  ...  39.0  7900  3.9  yes  yes   no  good  no  no            ckd
# 1  233.0  ...   NaN   NaN  NaN   no  yes   no  good  no  no            ckd
# 2  114.0  ...   NaN   NaN  NaN  yes   no   no  poor  no  no            ckd
# 3  108.0  ...  43.0  7200  5.5   no   no   no  good  no  no         notckd
# 4    NaN  ...  39.0  8300  4.6  yes   no   no  poor  no  no            ckd
#
# [5 rows x 25 columns]

# %%
df2.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data = pd.concat([df, df2])

# %%
data.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...  \
# 0   7  50  1.020  4  0     NaN    normal  notpresent  notpresent  NaN  ...
# 1  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 2  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 3  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
# 4  60  90  1.015  3  0     NaN       NaN  notpresent  notpresent   74  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  38  6000  NaN   no   no  no  good   no   no            ckd
# 1  31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 2  32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 3  35  7300  4.6   no   no  no  good   no   no            ckd
# 4  39  7800  4.4  yes  yes  no  good  yes   no            ckd
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (679, 25)

# %%
data.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (679, 25)

# %%
data.to_csv('chronic_kidney_diseases.csv')
